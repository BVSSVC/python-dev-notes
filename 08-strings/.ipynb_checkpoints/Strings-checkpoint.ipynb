# %% [markdown]
# ![image.png](attachment:eff52ae7-27a7-48db-b442-2ad09ced46d5.png)

# %% [markdown]
# <h1 align="center">Strings in Python</h1>
#
#
# Textual data in Python is handled with `str` objects, or strings.  Strings are **immutable sequences** of **Unicode code points**.
#
# Strings are also containers, because they hold a group of items (characters).
#
# String literals are written in a variety of ways:
#
# ```python
# # Single quotes
# s1 = 'allows embedded "double" quotes'
#
# # Double quotes
# s2 = "allows embedded 'single' quotes"
#
# # Triple single quotes (for multi-line or embedded quotes)
# s3 = '''Three single quotes'''
#
# # Triple double quotes (also useful for docstrings)
# s4 = """Three double quotes"""
# ```
# **Properties of string**
#
# | Property       | String supports? | Example                         |
# | -------------- | ---------------- | ------------------------------- |
# | **Sequence**   | ✅ Yes            | `s[0]`, `s[1:4]`, `for ch in s` |
# | **Container**  | ✅ Yes            | `'e' in s`, `len(s)`            |
# | **Mutable**    | ❌ No             | Strings are **immutable**       |
# | **Ordered**    | ✅ Yes            | Preserves character order       |
# | **Duplicates** | ✅ Yes            | Allows repeated characters      |

# %%
# Single word
'Hello'
# Out:
# 'Hello'

# %%
# Entire phase
"This is also a string"
# Out:
# 'This is also a string'

# %%
# single or dobule quotes
'String build with double quotes but we can also use single quotes'
# Out:
# 'String build with double quotes but we can also use single quotes'

# %%
# Be careful with quotes!
'I'm using single quotes but will create an error'
# Out:
#   Cell In[5], line 2
#     'I'm using single quotes but will create an error'
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
"Now I'm ready to use a single string."
# Out:
# "Now I'm ready to use a single string."

# %%
# printing a string
first_name = "Venkata Siva"
middle_name = "Sai Vardhan"
last_name = "Babburi"
print(first_name,last_name,middle_name)
# Out:
# Venkata Siva Babburi Sai Vardhan

# %%
# formatted-strings
print(f"My name is {first_name} {middle_name} {last_name}")
# Out:
# My name is Venkata Siva Sai Vardhan Babburi

# %%
# .format method
print("My name is {} {} {}".format(first_name,last_name,middle_name))
# Out:
# My name is Venkata Siva Babburi Sai Vardhan

# %% [markdown]
# ![image.png](attachment:b1cdaa8a-049f-4c74-becf-62be8548dd3d.png)
# ![image.png](attachment:831d0977-613e-48bf-9d10-a80161ce61e0.png)
# ![image.png](attachment:1432496d-aba9-45d8-8c03-df1631ae90bd.png)

# %%
name="sai vardhan"
print(type(name))
# Out:
# <class 'str'>

# %%
age =24
print("My age is:"+age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 age =24
# ----> 2 print("My age is:"+age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age =24
print("My age is:"+str(age))
age=age+5
age=str(age)
print(type(age))
# Out:
# My age is:24
# <class 'str'>

# %%
password="Bvss@8110"
print(len(password))
if len(password)<10:
    print("Your Password is too short")
# Out:
# 9
# Your Password is too short

# %%
# %%
text="""
python is easy to learn.
python is powerful
Many people love python
"""
text.count('python')
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:a84b0845-9592-4be1-b3ed-4bd1dc9d5cff.png)

# %%
price="12345,67"
print(price.replace(',','.'))
phone="166-1234-566"
print(phone.replace('-','/'))
phone="166-1234-566"
print(phone.replace('-',''))
phone="166-1234-566,123"
print(phone.replace('-','/').replace(",",""))
# Out:
# 12345.67
# 166/1234/566
# 1661234566
# 166/1234/566123

# %%
firstname='Michael'
last_name="Scott"
print(firstname+last_name)
print(firstname+' '+last_name)

folder="C:/Users/bsaiv"
file="strings.ipynb"
full_folder_path=folder+'/'+file
print(full_folder_path)
# Out:
# MichaelScott
# Michael Scott
# C:/Users/bsaiv/strings.ipynb

# %% [markdown]
# ![image.png](attachment:e44e8db3-22ad-4b67-84ae-b04306320963.png)

# %%
my_details="Sai Vardhan-24-INDIA"
print(my_details.split("-"))
csv_file="saivardhan,24,India,Male"
print(csv_file.split(","))
# Out:
# ['Sai Vardhan', '24', 'INDIA']
# ['saivardhan', '24', 'India', 'Male']

# %%
print("ha" * 3)
print("----------")
print("-"*10)
# Out:
# hahaha
# ----------
# ----------

# %% [markdown]
# ![download.png](attachment:30d1634a-4c3e-4a62-8177-07aceb101921.png)

# %%
a,b,c,d,e="hello"
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# ![download.png](attachment:3cc5bbed-113b-46d0-bfbe-c81293b1622b.png)

# %% [markdown]
# ![image.png](attachment:c863a1e5-a4aa-49a1-ae65-ac5fa4696674.png)

# %%
text = "Python"
print(text[-6])
print(text[5])
print(text[-1])
print(text[3])
# Out:
# P
# n
# n
# h

# %%
date="2026-12-26"
print(date[0:4])
print(date[:4])
print(date[5:7])
print(date[8:])
print(date[-2:])
# Out:
# 2026
# 2026
# 12
# 26
# 26

# %% [markdown]
# ![image.png](attachment:fc54661f-5b6e-4e51-948c-b0d45beb1f7f.png)

# %%
text="  Engineering"
print(text.lstrip())
text="Engineering  ".rstrip()
print(text)
text="    Engineering  ".strip()
print(text)
text="  Data  Engineering  ".strip()
print(text)
text="###ABC###".strip("#")
print(text)
text="    Engineering  "
print(len(text))
print(len(text.strip()))
nr_of_spaces=len(text)-len(text.strip())
is_clean=len(text)==len(text.strip())
print("Nr of spaces:",nr_of_spaces)
print("Is my data clean?",is_clean)
# Out:
# Engineering
# Engineering
# Engineering
# Data  Engineering
# ABC
# 17
# 11
# Nr of spaces: 6
# Is my data clean? False

# %% [markdown]
# ![image.png](attachment:e3ec5fb7-8902-483a-b4dd-858d7cbde74a.png)

# %%
text = "python PROGRAMMING"
print(text.lower())
print(text.upper())

search = "Email"
data = "email"
print(search == data)
search = "Email".lower()
data = "email".lower()
print(search == data)

search = "Email ".lower().strip()
data = "email".lower().strip()
print(search == data)
# Out:
# python programming
# PYTHON PROGRAMMING
# False
# True
# True

# %%
text='968-Maria, ( D@t@ Engineer );; 27y..'
s = text.rstrip(".; ")
print(s)
before_comma,after_comma=s.split(",",1)
print(before_comma)
print(after_comma)
emp_id,name=before_comma.split("-")
print(emp_id,type(emp_id))
print(name)
print(after_comma)
role_part = after_comma.split(")")[0]   # take until ')'
role=role_part.replace("(","").strip()
role = role.replace("@", "a").title()
print(role)
age_part = after_comma.split(")")[-1].strip()
age_part=age_part.replace(";","").strip()
age = age_part.replace("y", "").strip()
age = int(age)
print(age)
result = {
    "id": emp_id,
    "name": name,
    "role": role,
    "age": age
}

print(result)
# Out:
# 968-Maria, ( D@t@ Engineer );; 27y
# 968-Maria
#  ( D@t@ Engineer );; 27y
# 968 <class 'str'>
# Maria
#  ( D@t@ Engineer );; 27y
# Data Engineer
# 27
# {'id': '968', 'name': 'Maria', 'role': 'Data Engineer', 'age': 27}

# %% [markdown]
# ![image.png](attachment:89848f81-7cf4-4053-b045-52d920ac7454.png)

# %%
phone="+1612-203-9658"
print(phone.startswith("+1"))
phone="+1612-203-9658"
print(phone.startswith("+91"))

email='bsaivardhan7@gmail.com'
print(email.endswith("@gmail.com"))

file="data_backup.csv"
print(file.endswith(".csv"))


print("@" in email)

url = 'https://api.company.com/v1/date'
print("api" in url)


phone1="+1612-203-9658"
print(phone.find("-"))
print(phone[phone.find("-")+1:])
# Out:
# True
# False
# True
# True
# True
# True
# 5
# 203-9658

# %%
country = "USA"
print(country.isalpha())

country = "USA1"
print(country.isalpha())


phone = "61222039658"
print(phone.isnumeric())


phone = "6122203965-8"
print(phone.isnumeric())
# Out:
# True
# False
# True
# False
