# %% [markdown]
# ![image.png](attachment:afdf02b2-7bae-4c57-8c9a-a364e80d9d5e.png)

# %% [markdown]
# ![image.png](attachment:30653b8d-8f06-4777-83c4-860e4932755d.png)

# %%
# %%
my_set = {'a','b','c',True,100}
print(my_set,type(my_set),id(my_set))
# %%
my_book_set = set(('Harry Potter', 'Dungeons & Dragons', 'Atlas Shrugged'))
print(my_book_set,type(my_book_set),id(my_book_set))
# %%
# Out:
# {True, 'a', 100, 'c', 'b'} <class 'set'> 2393194391008
# {'Harry Potter', 'Atlas Shrugged', 'Dungeons & Dragons'} <class 'set'> 2393194391232

# %%
# %%
# list with duplicate items
number_list = [20, 30, 20, 30, 50, 30]
# create a set from a list
sample_set = set(number_list)
print(sample_set)
# Out:
# {50, 20, 30}

# %%
# set of mutable types
sample_set = {'Mark', 'Jessa', [35, 78, 92]}
print(sample_set)
# Output TypeError: unhashable type: 'list' [35, 78, 92]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # set of mutable types
# ----> 2 sample_set = {'Mark', 'Jessa', [35, 78, 92]}
#       3 print(sample_set)
#       4 # Output TypeError: unhashable type: 'list' [35, 78, 92]
#
# TypeError: unhashable type: 'list'

# %%
# %%
empty_set = set()
print(empty_set,type(empty_set))
# Out:
# set() <class 'set'>

# %%
emptySet = {}
print(type(emptySet)) # class 'dict'
# Out:
# <class 'dict'>

# %%
# %%
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
for book in book_set:
    print(book)
# Out:
# Harry Potter
# Angels and Demons
# Atlas Shrugged

# %%
# %%
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
if 'Harry Potter' in book_set:
    print("Book exists in the book set")
else:
    print("Book doesn't exists in the book set")
print("A man in Love" in book_set)
# Out:
# Book exists in the book set
# False

# %%
# create a set using set constructor
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
print(len(book_set))
# Out:
# 3

# %%
# %%
book_set = {'Harry Potter', 'Angels and Demons'}
# add() method
book_set.add('The God of small things.')
print(book_set)
book_set.update(["Alice in wonder Land","Wings of fire"])
print(book_set)
# Out:
# {'Harry Potter', 'Angels and Demons', 'The God of small things.'}
# {'Alice in wonder Land', 'The God of small things.', 'Wings of fire', 'Harry Potter', 'Angels and Demons'}

# %%
color_set = {'red', 'orange', 'yellow', 'white', 'black'}
color_set.remove('red')
print(color_set)
color_set.remove('black brown')
print(color_set)
# Out:
# {'yellow', 'black', 'white', 'orange'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 4
#       2 color_set.remove('red')
#       3 print(color_set)
# ----> 4 color_set.remove('black brown')
#       5 print(color_set)
#
# KeyError: 'black brown'

# %%
# %%
color_set = {'red', 'orange', 'yellow', 'white', 'black'}
color_set.remove('red')
print(color_set)
color_set.discard('black brown')
print(color_set)
# Out:
# {'yellow', 'black', 'white', 'orange'}
# {'yellow', 'black', 'white', 'orange'}

# %%
# %%
color_set = {'red', 'orange', 'yellow', 'white', 'black'}
color_set.pop()
print(color_set)
# Out:
# {'yellow', 'black', 'white', 'orange'}

# %% [markdown]
# ![image.png](attachment:f815c633-f2ed-4127-ba27-d54c2e9d83ec.png)

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set | remaining_colors
print(vibgyor)
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set.union(remaining_colors)
print(vibgyor)

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set & remaining_colors
print(vibgyor)
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set.intersection(remaining_colors)
print(vibgyor)
# Out:
# {'indigo'}
# {'indigo'}

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
color_set.intersection_update(remaining_colors)
print(color_set)
# Out:
# {'indigo'}

# %%
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set - remaining_colors
print(vibgyor)
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set.difference(remaining_colors)
print(vibgyor)
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
color_set.difference_update(remaining_colors)
print(color_set)
# Out:
# {'blue', 'violet', 'green', 'yellow'}
# {'blue', 'violet', 'green', 'yellow'}
# {'blue', 'green', 'yellow', 'violet'}

# %%
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set ^ remaining_colors
print(vibgyor)
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor = color_set.symmetric_difference(remaining_colors)
print(vibgyor)
# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
color_set.symmetric_difference_update(remaining_colors)
print(color_set)
# Out:
# {'green', 'red', 'yellow', 'blue', 'violet', 'orange'}
# {'green', 'red', 'yellow', 'blue', 'violet', 'orange'}
# {'blue', 'green', 'yellow', 'red', 'violet', 'orange'}

# %%
color_set = {'violet', 'blue', 'green', 'yellow'}

# creating a copy using copy()
color_set2 = color_set.copy()

# creating a copy using set()
color_set3 = set(color_set)

# creating a copy using = operator
color_set4 = color_set

# printing the original and new copies
print('Original set:', color_set)
# {'violet', 'green', 'yellow', 'blue'}

print('Copy using copy():', color_set2)
# {'green', 'yellow', 'blue', 'violet'}

print('Copy using set(): ', color_set3)
# {'green', 'yellow', 'blue', 'violet'}

print('Copy using assignment', color_set4)
# {'green', 'yellow', 'blue', 'violet'}
# Out:
# Original set: {'blue', 'violet', 'green', 'yellow'}
# Copy using copy(): {'blue', 'violet', 'green', 'yellow'}
# Copy using set():  {'blue', 'violet', 'green', 'yellow'}
# Copy using assignment {'blue', 'violet', 'green', 'yellow'}

# %%
# %%
color_set1 = {'violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red'}
color_set2 = {'indigo', 'orange', 'red'}
print(color_set1.issubset(color_set2))
print(color_set2.issubset(color_set1))
# %%
color_set1 = {'violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red'}
color_set2 = {'indigo', 'orange', 'red'}
print(color_set1.issuperset(color_set2))
print(color_set2.issuperset(color_set1))
# Out:
# False
# True
# True
# False

# %%
color_set1 = {'violet', 'blue', 'yellow', 'red'}
color_set2 = {'orange', 'red'}
color_set3 = {'green', 'orange'}
print(color_set2.isdisjoint(color_set1))
print(color_set3.isdisjoint(color_set1))
# Out:
# False
# True

# %% [markdown]
# ![image.png](attachment:a0e3b9ae-b959-4e6a-9f5f-e43c3bb5bb7e.png)

# %%
rainbow = ('violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red')
# create a frozenset
f_set = frozenset(rainbow)

print(f_set)
# output frozenset({'green', 'yellow', 'indigo', 'red', 'blue', 'violet', 'orange'})
# Out:
# frozenset({'green', 'yellow', 'red', 'blue', 'indigo', 'violet', 'orange'})

# %%
rainbow = ('violet', 'indigo', 'blue')
f_set = frozenset(rainbow)
# Add to frozenset
f_set.add(f_set)
# output AttributeError: 'frozenset' object has no attribute 'add'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       2 f_set = frozenset(rainbow)
#       3 # Add to frozenset
# ----> 4 f_set.add(f_set)
#       5 # output AttributeError: 'frozenset' object has no attribute 'add'
#
# AttributeError: 'frozenset' object has no attribute 'add'
